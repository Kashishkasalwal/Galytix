# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r"C:\Users\raosu\OneDrive\Documents\Exercise_data_Data_Analyst.xlsx", 2)

# %%
df.head()
# Out:
#                    variable_id                variable_name  lob iso2  unit  \
# 0                          gdp                     Real GDP  NaN   ae  rAED
# 1     real_private_consumption     Real private consumption  NaN   ae  rAED
# 2  real_government_consumption  Real government consumption  NaN   ae  rAED
# 3  real_gross_fixed_investment  Real gross fixed investment  NaN   ae  rAED
# 4           real_stockbuilding           Real stockbuilding  NaN   ae  rAED
#
#    comments          2001          2002          2003          2004  ...  \
# 0       NaN  6.527340e+11  6.686180e+11  7.274600e+11  7.970520e+11  ...
# 1       NaN  3.771300e+11  3.997340e+11  4.072720e+11  4.477840e+11  ...
# 2       NaN  4.676700e+10  4.943600e+10  5.237500e+10  5.482300e+10  ...
# 3       NaN  1.009440e+11  1.068030e+11  1.148680e+11  1.178640e+11  ...
# 4       NaN  3.553000e+09  3.626000e+09  3.586000e+09  3.934000e+09  ...
#
# ...

# %%
df1= pd.read_excel(r"C:\Users\raosu\OneDrive\Documents\Exercise_data_Data_Analyst.xlsx", 1)

# %%
df_realgdp=df[df['variable_name']=='Real GDP']

# %%
df_realgdp.head()
# Out:
#     variable_id variable_name  lob iso2  unit  comments          2001  \
# 0           gdp      Real GDP  NaN   ae  rAED       NaN  6.527340e+11
# 112         gdp      Real GDP  NaN   ao  rAOA       NaN  5.845850e+11
# 227         gdp      Real GDP  NaN   ar  rARS       NaN  5.067570e+11
# 352         gdp      Real GDP  NaN   at  rEUR       NaN  2.573930e+11
# 472         gdp      Real GDP  NaN   au  rAUD       NaN  1.074850e+12
#
#              2002          2003          2004  ...           2011  \
# 0    6.686180e+11  7.274600e+11  7.970520e+11  ...   990354000000
# 112  6.653850e+11  5.725590e+11  6.348510e+11  ...  1391950000000
# 227  4.515490e+11  4.919870e+11  5.358280e+11  ...   837791000000
# 352  2.611950e+11  2.634130e+11  2.697450e+11  ...   302985000000
# 472  1.117800e+12  1.151570e+12  1.198050e+12  ...  1453280000000
#
#               2012           2013          2014          2015          2016  \
# ...

# %%
df_realgdp.rename(columns={'iso2': 'Country'}, inplace=True)
# Out:
# C:\Users\raosu\Anaconda3\lib\site-packages\pandas\core\frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)

# %%
df_realgdp.head()
# Out:
#     variable_id variable_name  lob Country  unit  comments          2001  \
# 0           gdp      Real GDP  NaN      ae  rAED       NaN  6.527340e+11
# 112         gdp      Real GDP  NaN      ao  rAOA       NaN  5.845850e+11
# 227         gdp      Real GDP  NaN      ar  rARS       NaN  5.067570e+11
# 352         gdp      Real GDP  NaN      at  rEUR       NaN  2.573930e+11
# 472         gdp      Real GDP  NaN      au  rAUD       NaN  1.074850e+12
#
#              2002          2003          2004  ...           2011  \
# 0    6.686180e+11  7.274600e+11  7.970520e+11  ...   990354000000
# 112  6.653850e+11  5.725590e+11  6.348510e+11  ...  1391950000000
# 227  4.515490e+11  4.919870e+11  5.358280e+11  ...   837791000000
# 352  2.611950e+11  2.634130e+11  2.697450e+11  ...   302985000000
# 472  1.117800e+12  1.151570e+12  1.198050e+12  ...  1453280000000
#
#               2012           2013          2014          2015          2016  \
# ...

# %%
array=df_realgdp['Country']

# %%
array
# Out:
# 0       ae
# 112     ao
# 227     ar
# 352     at
# 472     au
# 598     az
# 721     bd
# 841     be
# 961     bg
# 1085    bh
# 1198    br
# 1324    ca
# 1444    ch
# 1564    cl
# 1690    cn
# 1814    co
# 1940    cr
# 2061    cu
# 2168    cy
# 2286    cz
# 2412    de
# 2532    dk
# 2652    do
# 2772    dz
# 2894    ec
# 3019    ee
# 3145    eg
# 3270    es
# 3394    fi
# 3514    fr
#         ..
# 5111    jp
# 5231    ke
# 5348    kr
# 5472    kw
# 5588    kz
# 5714    lk
# 5833    lt
# 5959    lv
# 6085    ly
# 6202    ma
# 6321    mx
# 6447    my
# 6573    ng
# 6693    nl
# 6813    no
# 6933    nz
# 7059    pe
# 7185    ph
# 7311    pk
# 7434    pl
# 7560    pt
# 7684    qa
# 7802    ro
# 7928    ru
# 8054    sa
# 8173    se
# 8293    sg
# 8412    si
# 8538    sk
# 8664    sv
# Name: Country, Length: 72, dtype: object

# %%
df1.head()
# Out:
#   variable_id variable_name       lob Country unit          comments  \
# 0    premiums      Premiums  aviation      ar  USD               NaN
# 1    premiums      Premiums    marine      ae  USD  Assumption based
# 2    premiums      Premiums  aviation      at  USD               NaN
# 3    premiums      Premiums    marine      ar  USD               NaN
# 4    premiums      Premiums  aviation      br  USD               NaN
#
#            2001          2002          2003          2004  ...          2006  \
# 0           NaN           NaN           NaN           NaN  ...           NaN
# 1           NaN           NaN           NaN           NaN  ...           NaN
# 2           NaN  3.440142e+07  3.491657e+07  2.872530e+07  ...  2.173151e+07
# 3           NaN           NaN           NaN           NaN  ...           NaN
# 4  8.731772e+07  1.196424e+08  1.429795e+08  1.250661e+08  ...  1.035521e+08
#
#            2007          2008          2009          2010          2011  \
# ...

# %%
df_air=df1[df1['lob']=='aviation']

# %%
df_marine=df1[df1['lob']=='marine']

# %%
year=np.array([2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015])

# %%
# Out:
# 0   NaN
# Name: 2001, dtype: float64

# %%
penetration_air=[];
y=0
for yr in year:
    penet=0
    x=0
    for cotr in array:
        x+=1
        z=(df_air[(df_air['Country']==cotr)][yr])/(df_realgdp[df_realgdp['Country']==cotr][yr])
        if z.notnull:
            penet+=x
    agg_penet=penet/x
    penetration_air.append(agg_penet)

# %%
penetration_marine=[];
y=0
for yr in year:
    penet=0
    x=0
    for cotr in array:
        x+=1
        z=(df_marine[(df_marine['Country']==cotr)][yr])/(df_realgdp[df_realgdp['Country']==cotr][yr])
        if z.notnull:
            penet+=x
    agg_penet=penet/x
    penetration_marine.append(agg_penet)

# %%
penetration_air
# Out:
# [36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5]

# %%
penetration_marine
# Out:
# [36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5,
#  36.5]
